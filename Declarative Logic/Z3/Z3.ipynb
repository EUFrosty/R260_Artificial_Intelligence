# %%
from z3 import *

# %%
n = 8
Q = [Int(f'Q_{i}') for i in range(n)]
val_c = [And(0 <= q, q < n) for q in Q]
col_c = [Distinct(Q)]
diag_c = [
    And(Q[i] - Q[j] != i - j, Q[i] - Q[j] != j - i) 
    for i in range(n) for j in range(i) if i != j
]
n_queens = val_c + col_c + diag_c
solve(n_queens)
# Out:
# [Q_3 = 5,
#  Q_1 = 1,
#  Q_7 = 6,
#  Q_5 = 2,
#  Q_4 = 0,
#  Q_0 = 3,
#  Q_2 = 7,
#  Q_6 = 4]

# %%
# U iskaznoj logici zapisati uslov da je 4-bitna reprezentacija broja
# palindrom, ali da nisu svi bitovi isti.
A,B,C,D = Bools('A B C D')

s = Solver()
s.add(A == D, B == C, Not(A == B))

while s.check() == sat:
    print(s.model())
    # Ispis svih modela. U ogranicenje dodamo negaciju prethodnog resenja.
    # s.model()[A] -> vrednost promenljive A u poslednjem modelu koji zadovoljava ogranicenja
    s.add(Not(And(A == s.model()[A], B == s.model()[B], C == s.model()[C], D == s.model()[D])))
# Out:
# [A = True, D = True, B = False, C = False]
# [A = False, D = False, B = True, C = True]

# %%
x, y, z = Reals('x y z')

s = Solver()
s.add(
    x + 5*y - 3*z == 4, # 1/2 +  7/2 = 8/2 = 4
    -x + y + z == 3,
    2*x + y - z == 1
)

if s.check() == sat:
    print(s.model())
    s.add(Not(And(x == s.model()[x], y== s.model()[y], z==s.model()[z])))
# Out:
# [y = 0, x = 0, z = 0]

# %%
x, y, z = Reals('x y z')
s = Solver()
s.add(x > 1, y > 1, x + y > 3, z - x < 10)
print(s.check())

m = s.model()
print("x = %s" % m[x])

print("traversing model...")
for d in m.decls():
    print("%s = %s" % (d.name(), m[d]))
# Out:
# sat
# x = 3/2
# traversing model...
# y = 2
# x = 3/2
# z = 0

# %%
# Dve nemimoilazne prave se seku ili su paralelne.
# Prave koje se seku leže u istoj ravni.
# Prave koje su paralelene leže u istoj ravni.
# Dve nemimoilazne prave leže u istoj ravni.

# m(X,Y) - X i Y su nemimoilazne: m: PxP -> B
# s(X,Y) - X i Y se seku: s: PxP -> B
# p(X,Y) - X i Y su paralelne: p: PxP -> B
# r(X,Y) - X i Y leze u istoj ravni: r: PxP -> B

B = BoolSort()
P = DeclareSort('Prave')
m = Function('m', P, P, B)
s = Function('s', P, P, B)
p = Function('p', P, P, B)
r = Function('r', P, P, B)

x, y = Consts('x y', P)

solver = Solver()
axioms = [
    ForAll([x,y], Implies(m(x,y), Or(s(x,y), p(x,y)))),
    ForAll([x,y], Implies(s(x,y), r(x,y))),
    ForAll([x,y], Implies(p(x,y), r(x,y)))
]
conjecture = ForAll([x,y], Implies(m(x,y), r(x,y)))

solver.add(conjecture)
solver.add(axioms)
while solver.check() == sat:
    print(solver.model())
    solver.add(Not(And(x == solver.model()[x], y == solver.model()[y])))
# Out:
# [p = [else -> False],
#  m = [else -> False],
#  r = [else -> False],
#  s = [else -> False]]
# [s = [else -> False],
#  m = [else -> False],
#  r = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
# ...
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# [s = [else -> False],
#  r = [else -> False],
#  m = [else -> False],
#  p = [else -> False]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 31
#      29 solver.add(axioms)
#      30 while solver.check() == sat:
# ---> 31     print(solver.model())
#      32     solver.add(Not(And(x == solver.model()[x], y == solver.model()[y])))
#
# File ~/.local/lib/python3.10/site-packages/z3/z3.py:6381, in ModelRef.__repr__(self)
#    6380 def __repr__(self):
# -> 6381     return obj_to_string(self)
#
# File ~/.local/lib/python3.10/site-packages/z3/z3printer.py:1434, in obj_to_string(a)
#    1432 def obj_to_string(a):
#    1433     out = io.StringIO()
# -> 1434     _PP(out, _Formatter(a))
#    1435     return out.getvalue()
#
# File ~/.local/lib/python3.10/site-packages/z3/z3printer.py:1327, in Formatter.__call__(self, a)
#    1325 def __call__(self, a):
#    1326     self.visited = 0
# -> 1327     return self.main(a)
#
# File ~/.local/lib/python3.10/site-packages/z3/z3printer.py:1317, in Formatter.main(self, a)
#    1315     return self.pp_seq_seq(a, 0, [])
#    1316 elif isinstance(a, z3.ModelRef):
# -> 1317     return self.pp_model(a)
#    1318 elif isinstance(a, z3.FuncInterp):
#    1319     return self.pp_func_interp(a)
#
# File ~/.local/lib/python3.10/site-packages/z3/z3printer.py:1240, in Formatter.pp_model(self, m)
#    1238 i = m[d]
#    1239 if isinstance(i, z3.FuncInterp):
# -> 1240     i_pp = self.pp_func_interp(i)
#    1241 else:
#    1242     i_pp = self.pp_expr(i, 0, [])
#
# File ~/.local/lib/python3.10/site-packages/z3/z3printer.py:1278, in Formatter.pp_func_interp(self, f)
#    1276         else_pp = to_format("#unspecified")
#    1277     else:
# -> 1278         else_pp = self.pp_expr(else_val, 0, [])
#    1279     r.append(group(seq((to_format("else"), else_pp), self.pp_arrow())))
#    1280 return seq3(r, "[", "]")
#
# File ~/.local/lib/python3.10/site-packages/z3/z3printer.py:1198, in Formatter.pp_expr(self, a, d, xs)
#    1196     return self.pp_ellipses()
#    1197 if z3.is_app(a):
# -> 1198     return self.pp_app(a, d, xs)
#    1199 elif z3.is_quantifier(a):
#    1200     return self.pp_quantifier(a, d, xs)
#
# File ~/.local/lib/python3.10/site-packages/z3/z3printer.py:1121, in Formatter.pp_app(self, a, d, xs)
#    1119 elif z3.is_finite_domain_value(a):
#    1120     return self.pp_fd(a)
# -> 1121 elif z3.is_fprm_value(a):
#    1122     return self.pp_fprm_value(a)
#    1123 elif z3.is_fp_value(a):
#
# File ~/.local/lib/python3.10/site-packages/z3/z3.py:9731, in is_fprm_value(a)
#    9729 def is_fprm_value(a):
#    9730     """Return `True` if `a` is a Z3 floating-point rounding mode numeral value."""
# -> 9731     return is_fprm(a) and _is_numeral(a.ctx, a.ast)
#
# File ~/.local/lib/python3.10/site-packages/z3/z3.py:9726, in is_fprm(a)
#    9716 def is_fprm(a):
#    9717     """Return `True` if `a` is a Z3 floating-point rounding mode expression.
#    9718
#    9719     >>> rm = RNE()
#    (...)
#    9724     False
#    9725     """
# -> 9726     return isinstance(a, FPRMRef)
#
# KeyboardInterrupt:

# %%
#Svaka dva brata imaju zajednickog roditelja
#Roditelj je stariji od deteta
#Postoje braca
#Ni jedna osoba nije starija od druge

#b: OxO - > B
 
B = BoolSort()
O = DeclareSort('Osoba')



b = Function('braca', O, O, B)
r = Function('roditelj', O, O, B)
s = Function('starija', O, O, B)

x,y,z = Consts('x y z',O)

solver = Solver()

axioms = [
    ForAll([x, y], Exists([z], Implies(b(x,y), And(r(z,x), r(z,y))))),
    ForAll([x,y], Implies(r(x, y), s(x, y))),
    Exists([x,y], b(x, y))
]

conjecture = ForAll([x, y], Not(s(x, y)))

solver.add(conjecture)
solver.add(axioms)
while solver.check() == sat:
    print(solver.model())
    solver.add(Not(And(x == solver.model()[x], y == solver.model()[y], z == solver.model()[z])))
solver.check()

# %%
##N DAMA

n = 8
Q = [Int(f'Q_{i}') for i in range(n)]

val_c = [And(0 <= q, q < n) for q in Q]
col_c = [Distinct(Q)]
diag_c = [
    And(Q[i] - Q[j] != i-j, Q[i] - Q[j] != j-i) for i in range(n) for j in range(i) if i != j
]

n_queens = val_c + col_c + diag_c

solve(n_queens)
# Out:
# [Q_3 = 5,
#  Q_1 = 1,
#  Q_7 = 6,
#  Q_5 = 2,
#  Q_4 = 0,
#  Q_0 = 3,
#  Q_2 = 7,
#  Q_6 = 4]

# %%
##SUDOKU
X = [ [ Int("x_%s_%s" % (i+1, j+1)) for j in range(9) ] for i in range(9) ]

cells_c  = [ And(1 <= X[i][j], X[i][j] <= 9) for i in range(9) for j in range(9) ]
rows_c   = [ Distinct(X[i]) for i in range(9) ]
cols_c   = [ Distinct([ X[i][j] for i in range(9) ]) for j in range(9) ]
sq_c     = [ Distinct([ X[3*i0 + i][3*j0 + j] for i in range(3) for j in range(3) ])
            for i0 in range(3) for j0 in range(3) ]
sudoku_c = cells_c + rows_c + cols_c + sq_c

instance = ((0,0,0,0,9,4,0,3,0),
            (0,0,0,5,1,0,0,0,7),
            (0,8,9,0,0,0,0,4,0),
            (0,0,0,0,0,0,2,0,8),
            (0,6,0,2,0,1,0,5,0),
            (1,0,2,0,0,0,0,0,0),
            (0,7,0,0,0,0,5,2,0),
            (9,0,0,0,6,5,0,0,0),
            (0,4,0,9,7,0,0,0,0))

instance_c = [ If(instance[i][j] == 0, 
                  True, 
                  X[i][j] == instance[i][j]) 
               for i in range(9) for j in range(9) ]

s = Solver()
s.add(sudoku_c + instance_c)
if s.check() == sat:
    m = s.model()
    r = [ [ m.evaluate(X[i][j]) for j in range(9) ] 
          for i in range(9) ]
    print_matrix(r)
else:

    print("failed to solve")
# Out:
# [[7, 1, 5, 8, 9, 4, 6, 3, 2],
#  [2, 3, 4, 5, 1, 6, 8, 9, 7],
#  [6, 8, 9, 7, 2, 3, 1, 4, 5],
#  [4, 9, 3, 6, 5, 7, 2, 1, 8],
#  [8, 6, 7, 2, 3, 1, 9, 5, 4],
#  [1, 5, 2, 4, 8, 9, 7, 6, 3],
#  [3, 7, 6, 1, 4, 8, 5, 2, 9],
#  [9, 2, 8, 3, 6, 5, 4, 7, 1],
#  [5, 4, 1, 9, 7, 2, 3, 8, 6]]

# %%
def is_contradictory(self):
    variables = list(self.get_all_variables())
    for valuation in all_valuations(variables):
        if self.interpret(valuation) == True:
            return False
    return True
